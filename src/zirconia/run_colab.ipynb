# %%
# %run 02_interpret_mechanisms.py
# Out:
# >>> Paths Configuration:
#     Results Dir: D:\workspace\project2026\material-conductivity-suite\data-analysis-ml\results
#     Image Dir:   D:\workspace\project2026\material-conductivity-suite\data-analysis-ml\results\images
# >>> [Data Processor] Executing SQL Extraction and Transformation...
# >>> [Data Processor] Data loaded successfully. Shape: (1351, 14)
#
# [Experiment 1] Visualizing Latent Chemical Space (t-SNE)...
#    Training analysis model for 60 epochs on 1351 samples...
#    -> Saved 'D:\workspace\project2026\material-conductivity-suite\data-analysis-ml\results\images\paper_latent_space.png'
#
# [Experiment 2] Analyzing What Drives Activation Energy (Permutation Importance)...
#    -> Saved 'D:\workspace\project2026\material-conductivity-suite\data-analysis-ml\results\images\paper_feature_importance_Ea.png'
#
# [Experiment 3] Zero-Shot Discovery: Leave-One-Dopant-Out...
#    Training analysis model for 80 epochs on 909 samples...
# ...
